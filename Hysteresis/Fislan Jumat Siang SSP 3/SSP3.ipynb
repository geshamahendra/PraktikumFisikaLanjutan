# %%
import pandas as pd
import os
# %matplotlib inline

data_v11 = pd.read_csv('./4/1/v1.txt', sep = '\t', index_col = 0)

# %%
data_v11[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
# Out:
#                   Current I_A1 / A  Magnetic flux &F / Vs
# DEF="Time" t / s
# 0.000                       0.0005               0.000000
# 0.049                       0.0020               0.000000
# 0.099                       0.0025               0.000825
# 0.150                       0.0055               0.002699
# 0.199                       0.0085               0.004929
# ...                            ...                    ...
# 28.299                     -0.0200              -0.086296
# 28.350                     -0.0155              -0.080201
# 28.400                     -0.0115              -0.073926
# 28.449                     -0.0070              -0.067495
# 28.500                     -0.0030              -0.060495
#
# [571 rows x 2 columns]

# %%
data_v11.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v151 = pd.read_csv('./4/1/v1.5.txt', sep = '\t', index_col = 0)
data_v151[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v151.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v21 = pd.read_csv('./4/1/v2.txt', sep = '\t', index_col = 0)
data_v21[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v21.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v251 = pd.read_csv('./4/1/v2.5.txt', sep = '\t', index_col = 0)
data_v251[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v251.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v31 = pd.read_csv('./4/1/v3.txt', sep = '\t', index_col = 0)
data_v31[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v31.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v12= pd.read_csv('./4/2/v1.txt', sep = '\t', index_col = 0)
data_v12[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v12.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v152= pd.read_csv('./4/2/v1.5.txt', sep = '\t', index_col = 0)
data_v152[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v152.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v22= pd.read_csv('./4/2/v2.txt', sep = '\t', index_col = 0)
data_v22[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v22.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v252= pd.read_csv('./4/2/v2.5.txt', sep = '\t', index_col = 0)
data_v252[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v252.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v32= pd.read_csv('./4/2/v3.txt', sep = '\t', index_col = 0)
data_v32[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v32.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v13= pd.read_csv('./4/3/v1.txt', sep = '\t', index_col = 0)
data_v13[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v13.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v153= pd.read_csv('./4/3/v1.5.txt', sep = '\t', index_col = 0)
data_v153[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v153.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v23= pd.read_csv('./4/3/v2.txt', sep = '\t', index_col = 0)
data_v23[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v23.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v253= pd.read_csv('./4/3/v2.5.txt', sep = '\t', index_col = 0)
data_v253[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v253.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v33= pd.read_csv('./4/3/v3.txt', sep = '\t', index_col = 0)
data_v33[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v33.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v14= pd.read_csv('./4/4/v1.txt', sep = '\t', index_col = 0)
data_v14[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v14.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v154= pd.read_csv('./4/4/v1.5.txt', sep = '\t', index_col = 0)
data_v154[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v154.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v24= pd.read_csv('./4/4/v2.txt', sep = '\t', index_col = 0)
data_v24[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v24.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v254= pd.read_csv('./4/4/v2.5.txt', sep = '\t', index_col = 0)
data_v254[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v254.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v34= pd.read_csv('./4/4/v3.txt', sep = '\t', index_col = 0)
data_v34[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v34.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v15= pd.read_csv('./4/5/v1.txt', sep = '\t', index_col = 0)
data_v15[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v15.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v155= pd.read_csv('./4/5/v1.5.txt', sep = '\t', index_col = 0)
data_v155[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v155.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v25= pd.read_csv('./4/5/v2.txt', sep = '\t', index_col = 0)
data_v25[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v25.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v255= pd.read_csv('./4/5/v2.5.txt', sep = '\t', index_col = 0)
data_v255[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v255.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v35= pd.read_csv('./4/5/v3.txt', sep = '\t', index_col = 0)
data_v35[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v35.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v15demag= pd.read_csv('./4/5demag/v1.txt', sep = '\t', index_col = 0)
data_v15demag[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v15demag.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v155= pd.read_csv('./4/5/v1.5.txt', sep = '\t', index_col = 0)
data_v155[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v155.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v25= pd.read_csv('./4/5/v2.txt', sep = '\t', index_col = 0)
data_v25[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v25.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v255= pd.read_csv('./4/5/v2.5.txt', sep = '\t', index_col = 0)
data_v255[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v255.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>

# %%
data_v35= pd.read_csv('./4/5/v3.txt', sep = '\t', index_col = 0)
data_v35[['Current I_A1 / A', 'Magnetic flux &F / Vs']]
data_v35.plot('Current I_A1 / A', 'Magnetic flux &F / Vs')
# Out:
# <AxesSubplot:xlabel='Current I_A1 / A'>
